# %%
import numpy as np
import scipy as sp
import pandas as pd

from sklearn.preprocessing import Imputer

#read the csv into a dataframe
df = pd.read_csv('GEPData.csv')

# %%
df
# Out:
#                                          Country Name Country Code  \
# 0                                  Advanced Economies          AME
# 1                                               BRICs          BRC
# 2                                Developing Countries          DEV
# 3                            EMDE Commodity Exporters          EDE
# 4                            EMDE Commodity Importers          EDI
# 5                EMDE Commodity Importers excl. China          EDX
# 6                                EMDE EAP excl. China          EAO
# 7                    EMDE East Asia and Pacific (EAP)          EAA
# 8                               EMDE ECA Central Asia          CAC
# 9                             EMDE ECA Central Europe          EHE
# 10                            EMDE ECA Eastern Europe          EUO
# 11                            EMDE ECA South Caucasus          SCC
# 12                           EMDE ECA Western Balkans          WBK
# 13                 EMDE Europe and Central Asia (ECA)          ECH
# 14   EMDE Europe and Central Asia Commodity Exporters          ECE
# 15   EMDE Europe and Central Asia Commodity Importers          EEE
# 16                                 EMDE LAC Caribbean          LNI
# 17                           EMDE LAC Central America          LNA
# 18                             EMDE LAC South America          LNS
# 19             EMDE Latin America and Caribbean (LAC)          LAP
# 20            EMDE Middle East and North Africa (MNA)          MNH
# 21                             EMDE MNA GCC countries          GCC
# 22                             EMDE MNA Oil exporters          MOX
# 23                             EMDE MNA Oil importers          MOM
# 24                               EMDE SAR excl. India          SAI
# 25                       EMDE South Asia Region (SAR)          SAP
# 26                             EMDE SSA CFA countries          SFA
# 27                        EMDE SSA excl. South Africa          SSA
# 28                             EMDE SSA Oil exporters          SOX
# 29                      EMDE Sub-Saharan Africa (SSA)          SSP
# ..                                                ...          ...
# 189                                             Sudan          SDN
# 190                                          Suriname          SUR
# 191                                         Swaziland          SWZ
# 192                                            Sweden          SWE
# 193                                       Switzerland          CHE
# 194                                     Taiwan, China          TWN
# 195                                        Tajikistan          TJK
# 196                             Tanzania, United Rep.          TZA
# 197                                          Thailand          THA
# 198                                       Timor-Leste          TMP
# 199                                              Togo          TGO
# 200                                             Tonga          TON
# 201                               Trinidad and Tobago          TTO
# 202                                           Tunisia          TUN
# 203                                            Turkey          TUR
# 204                                      Turkmenistan          TKM
# 205                                            Tuvalu          TUV
# 206                                            Uganda          UGA
# 207                                           Ukraine          UKR
# 208                              United Arab Emirates          ARE
# 209                                    United Kingdom          GBR
# 210                                     United States          USA
# 211                                           Uruguay          URY
# 212                                        Uzbekistan          UZB
# 213                                           Vanuatu          VUT
# 214                                     Venezuela, RB          VEN
# 215                                           Vietnam          VNM
# 216                                West Bank and Gaza          WBG
# 217                                            Zambia          ZMB
# 218                                          Zimbabwe          ZWE
#
#                     Indicator Name Indicator Code  1999  2000       2001  \
# 0    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   1.514662
# 1    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   5.090155
# 2    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   3.439045
# 3    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   2.588319
# 4    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   3.826022
# 5    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   1.204358
# 6    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   3.244627
# 7    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   6.713382
# 8    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN  11.491183
# 9    GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   2.723372
# 10   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   8.099741
# 11   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   8.477958
# 12   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   4.450382
# 13   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   2.557277
# 14   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   5.709569
# 15   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   2.449580
# 16   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   1.747244
# 17   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN  -0.294545
# 18   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   1.018091
# 19   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   0.687972
# 20   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN   1.611581
# 21   GDP growth, constant 2010 USD   NYGDPMKTPKDZ   NaN   NaN
# 0            NaN
# 1            NaN
# 2            NaN
# 3            NaN
# 4            NaN
# 5            NaN
# 6            NaN
# 7            NaN
# 8            NaN
# 9            NaN
# 10           NaN
# 11           NaN
# 12           NaN
# 13           NaN
# 14           NaN
# 15           NaN
# 16           NaN
# 17           NaN
# 18           NaN
# 19           NaN
# 20           NaN
# 21           NaN
# 22           NaN
# 23           NaN
# 24           NaN
# 25           NaN
# 26           NaN
# 27           NaN
# 28           NaN
# 29           NaN
# ..           ...
# 189          NaN
# 190          NaN
# 191          NaN
# 192          NaN
# 193          NaN
# 194          NaN
# 195          NaN
# 196          NaN
# 197          NaN
# 198          NaN
# 199          NaN
# 200          NaN
# 201          NaN
# 202          NaN
# 203          NaN
# 204          NaN
# 205          NaN
# 206          NaN
# 207          NaN
# 208          NaN
# 209          NaN
# 210          NaN
# 211          NaN
# 212          NaN
# 213          NaN
# 214          NaN
# 215          NaN
# 216          NaN
# 217          NaN
# 218          NaN
#
# [219 rows x 26 columns]

# %%
import os
import pandas as pd
import numpy as np
from IPython.core.display import display, HTML
import pymongo
from pymongo import MongoClient

# %%
print('Mongo version', pymongo.__version__)
client = MongoClient('ip', 27017)
db = client.test
collection = db.gdpAggregations
# Out:
# Mongo version 3.5.1

# %%
cur = collection.find().limit(3)
print(cur)
# Out:
# <pymongo.cursor.Cursor object at 0x000002228FE4D208>

# %%
x = collection.find().limit(3)
for doc in x:
    print(doc)
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-19-682383f72084> in <module>()
#       1 x = collection.find().limit(3)
# ----> 2 for doc in x:
#       3     print(doc)
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\cursor.py in next(self)
#    1130         if self.__empty:
#    1131             raise StopIteration
# -> 1132         if len(self.__data) or self._refresh():
#    1133             if self.__manipulate:
#    1134                 _db = self.__collection.database
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\cursor.py in _refresh(self)
#    1053                                        self.__batch_size,
#    1054                                        self.__read_concern,
# -> 1055                                        self.__collation))
#    1056             if not self.__id:
#    1057                 self.__killed = True
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\cursor.py in __send_message(self, operation)
#     890             try:
#     891                 response = client._send_message_with_response(operation,
# --> 892                                                               **kwargs)
#     893                 self.__address = response.address
#     894                 if self.__exhaust:
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\mongo_client.py in _send_message_with_response(self, operation, read_preference, exhaust, address)
#     931         else:
#     932             selector = read_preference or writable_server_selector
# --> 933             server = topology.select_server(selector)
#     934
#     935         # A _Query's slaveOk bit is already set for queries with non-primary
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\topology.py in select_server(self, selector, server_selection_timeout, address)
#     212         return random.choice(self.select_servers(selector,
#     213                                                  server_selection_timeout,
# --> 214                                                  address))
#     215
#     216     def select_server_by_address(self, address,
#
# C:\Users\amrut\Anaconda3\lib\site-packages\pymongo\topology.py in select_servers(self, selector, server_selection_timeout, address)
#     187                 if server_timeout == 0 or now > end_time:
#     188                     raise ServerSelectionTimeoutError(
# --> 189                         self._error_message(selector))
#     190
#     191                 self._ensure_opened()
#
# ServerSelectionTimeoutError: 192.168.91.23:27017: [WinError 10061] No connection could be made because the target machine actively refused it
